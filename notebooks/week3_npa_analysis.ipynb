# %% [markdown]
# 1. Overall NPA Analysis
# Interpretation:
#
# Overall portfolio NPA rate is 11.90%.
#
# NPA rate increases significantly as loan grade deteriorates.
#
# Grade G loans have the highest NPA rate (38.08%), while Grade A loans have the lowest (3.28%).
#
# This confirms that lower credit-quality borrowers contribute most to portfolio risk.
#
# 2. Home Ownership Analysis
# Interpretation:
#
# Renters show higher NPA rates (13.89%) compared to mortgage holders (10.32%).
#
# Home ownership appears to be associated with better repayment behavior.
#
# Rent-based borrowers represent a higher-risk segment.
#
# 3. Purpose-Based Risk Analysis
# Interpretation:
#
# Small business loans have the highest NPA rate (18.67%).
#
# Educational and renewable energy loans also show elevated risk levels.
#
# Debt consolidation loans contribute a large share of defaults because of their volume and relatively high NPA rate.
#
# 4. Vintage Analysis
# Interpretation:
#
# The worst-performing vintage year is 2015 with an NPA rate of 18.00%.
#
# NPA rates decline sharply after 2016.
#
# Recent vintages (2017–2018) show much lower default rates, indicating improved portfolio quality and underwriting standards.
#
# 5. Repayment Health Metrics
# Interpretation:
#
# Fully Paid loans account for 47.69% of the portfolio.
#
# Current loans account for 38.90%.
#
# Charged-off loans account for 11.89%.
#
# Overall repayment health remains stable, with the majority of loans performing normally.
#
# 6. Early Warning Indicators
# Interpretation:
#
# High-risk loan flagging identified 29,538 loans.
#
# These loans require closer monitoring because they exhibit characteristics associated with higher default probability.
#
# High-risk accounts represent the most
